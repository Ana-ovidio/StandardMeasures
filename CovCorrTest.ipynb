# %%
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
stocks_frame = pd.DataFrame(np.random.randn(366,100))
display(stocks_frame)
# Out:
#            0         1         2         3         4         5         6   \
# 0    1.258246 -0.793783  1.882173 -0.542738 -1.228267  2.964056 -1.262686
# 1    1.202358  2.394649  0.468420  0.972526  0.948814 -0.293841 -0.149061
# 2    1.109189  0.820340 -0.759217  0.952293  0.935410 -0.239069  0.819935
# 3    0.876335  1.984573  2.891223 -0.325097  1.040254  1.784770 -0.849701
# 4    0.598388  0.409240  1.694088  0.088001 -1.185301 -0.799358 -0.875854
# ..        ...       ...       ...       ...       ...       ...       ...
# 361  0.051286 -1.881959 -0.138974 -1.017767  0.058002  1.507784  0.340837
# 362 -2.277344  0.347233  0.322345 -0.100146 -0.464785  0.227033 -0.759788
# 363 -1.500903 -0.702190 -0.316154 -0.044596 -1.291847  1.167390  1.849743
# 364 -2.237855 -1.790713 -0.082723 -0.506299  0.456499  1.025385  0.307090
# 365 -1.427329  0.340984 -0.476118  0.863579  0.735626  0.227478 -0.530993
#
#            7         8         9   ...        90        91        92  \
# 0   -1.290020  1.170483  0.706948  ...  1.001462 -0.988012  0.560389
# 1   -0.782356 -1.242934  0.292349  ... -0.060457  0.117952  3.694599
# 2    0.783708 -0.589799 -0.493709  ... -0.356723 -0.825355  0.999347
# 3   -0.611972  0.724009 -0.863397  ... -1.225909 -0.797909  1.006805
# 4   -0.308463 -1.122617 -2.234221  ...  0.200346  0.360162 -0.781851
# ..        ...       ...       ...  ...       ...       ...       ...
# 361  0.223772 -0.433768  1.765281  ... -1.558937 -0.048906  0.460901
# 362  0.784828  1.130972  0.158397  ...  0.733369 -0.112960 -0.195878
# 363  0.434414 -1.115085 -1.046644  ...  1.181431 -0.324359 -0.186844
# 364 -0.128779 -0.065116  0.436267  ... -1.024206 -0.268231 -1.025819
# 365  0.749576 -0.150040  0.743430  ...  0.763542  0.415442 -2.397822
#
#            93        94        95        96        97        98        99
# 0    0.492214  0.200796 -0.157982 -0.413151  0.961337  0.152869 -1.605511
# 1    1.090331  0.192795 -1.585480 -3.597550  0.967851 -0.712699  2.445213
# 2   -0.555260  1.397530  0.582542  0.799468  1.137627  0.633831 -0.449708
# 3   -0.307355 -1.256294 -1.553630  0.025649  1.491230 -0.259118  0.125751
# 4   -0.708436  0.491040 -1.093178 -0.726711 -1.477000 -0.166889 -0.686264
# ..        ...       ...       ...       ...       ...       ...       ...
# 361 -0.257958 -1.641161  0.990651  1.910867 -0.602714  1.182444 -0.540468
# 362  0.013117  0.012605 -0.009141 -0.292133  0.810296 -0.420413 -1.164004
# 363  0.002862  1.087947 -1.267061  0.019048 -0.722825 -0.045011 -0.284568
# 364 -1.057064  0.024302  1.284476  0.156905  0.440884  1.257246 -0.172815
# 365  0.584000  0.356212  2.424022 -1.834925 -1.087385  1.688361  0.384705
#
# [366 rows x 100 columns]

# %% [markdown]
# -----------
# **Estima a variação entre os dias**

# %%
variations = []
for i in range(1,len(stocks_frame)):
    variation = stocks_frame.iloc[i] - stocks_frame.iloc[i-1]
    variation_dic = variation.to_dict()
    variations.append(variation_dic)

# %%
stcks_prcs_vr = pd.DataFrame(variations)

# %%
stcks_prcs_vr
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0
# 362 -0.010255  1.075342 -1.257919  0.311181 -1.533121  0.375403  0.879436
# 363 -1.059927 -1.063646  2.551537  0.137857  1.163708  1.302256  0.111753
# 364  1.641064  0.331910  1.139545 -1.991830 -1.528269  0.431115  0.557520
#
# [365 rows x 100 columns]

# %% [markdown]
# -------------
# **Estima a matriz de covariância e a covariância média**

# %%
list_prices = []
for i in range(len(stcks_prcs_vr)):
    list_prices.append(stcks_prcs_vr.iloc[i][:].tolist())
matrix_prices = np.array(list_prices)

# %%
cov_matrix = np.cov(matrix_prices,bias=True)
corr_matrix = np.corrcoef(matrix_prices)

# %%
valeus_outside_diagonal = []
for i, dataset in enumerate(cov_matrix):
    for j in range(i):
        valeus_outside_diagonal.append(dataset[j])

# %%
mean_cov = np.mean(valeus_outside_diagonal)
mean_cov
# Out:
# -0.005313055876281554

# %%
all_cov_mean = []
days = 9000

# %%
for day in tqdm(range(days)):
    stocks_frame = pd.DataFrame(np.random.randn(366,100))
    
    variations = []
    for i in range(1,len(stocks_frame)):
        variation = stocks_frame.iloc[i] - stocks_frame.iloc[i-1]
        variation_dic = variation.to_dict()
        variations.append(variation_dic) 
        
    stcks_prcs_vr = pd.DataFrame(variations) 
    
    list_prices = []
    for i in range(len(stcks_prcs_vr.columns)):
        list_prices.append(stcks_prcs_vr.iloc[:][i].tolist())
    matrix_prices = np.array(list_prices)
    cov_matrix = np.cov(matrix_prices,bias=True)
    
    valeus_outside_diagonal = []
    for i, dataset in enumerate(cov_matrix):
        for j in range(i):
            valeus_outside_diagonal.append(dataset[j])
            
    mean_cov = np.mean(valeus_outside_diagonal)
    all_cov_mean.append(mean_cov)
# Out:
#   0%|▎                                                                               | 31/9000 [00:08<42:49,  3.49it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-c34c99d14e06> in <module>
#       4     variations = []
#       5     for i in range(1,len(stocks_frame)):
# ----> 6         variation = stocks_frame.iloc[i] - stocks_frame.iloc[i-1]
#       7         variation_dic = variation.to_dict()
#       8         variations.append(variation_dic)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1496             self._validate_integer(key, axis)
#    1497
# -> 1498             return self.obj._ixs(key, axis=axis)
#    1499
#    1500     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _ixs(self, i, axis)
#    2831             # if we are a copy, mark as such
#    2832             copy = isinstance(new_values, np.ndarray) and new_values.base is None
# -> 2833             result = self._constructor_sliced(
#    2834                 new_values,
#    2835                 index=self.columns,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     247                 data = {}
#     248             if dtype is not None:
# --> 249                 dtype = self._validate_dtype(dtype)
#     250
#     251             if isinstance(data, MultiIndex):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _validate_dtype(cls, dtype)
#     251         """ validate the passed dtype """
#     252         if dtype is not None:
# --> 253             dtype = pandas_dtype(dtype)
#     254
#     255             # a compound dtype
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\dtypes\common.py in pandas_dtype(dtype)
#    1748     """
#    1749     # short-circuit
# -> 1750     if isinstance(dtype, np.ndarray):
#    1751         return dtype.dtype
#    1752     elif isinstance(dtype, (np.dtype, ExtensionDtype)):
#
# KeyboardInterrupt:
